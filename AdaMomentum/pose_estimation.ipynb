# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.metrics import f1_score, precision_score, recall_score
import matplotlib.pyplot as plt
import numpy as np

# AdaMomentum optimizer class
class AdaMomentum(optim.Optimizer):
    def __init__(self, params, lr=0.001, betas=(0.9, 0.999), eps=1e-8, weight_decay=0):
        defaults = dict(lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
        super(AdaMomentum, self).__init__(params, defaults)

    def step(self, closure=None):
        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data
                state = self.state[p]

                if len(state) == 0:
                    state['step'] = 0
                    state['m'] = torch.zeros_like(p.data)
                    state['v'] = torch.zeros_like(p.data)
                    state['v_hat_prev'] = torch.zeros_like(p.data)

                m, v = state['m'], state['v']
                beta1, beta2 = group['betas']
                state['step'] += 1

                m.mul_(beta1).add_(grad, alpha=1 - beta1)
                v.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)

                m_hat = m / (1 - beta1 ** state['step'])
                v_hat = v / (1 - beta2 ** state['step'])

                if state['step'] == 1:
                    eta_t = group['lr']
                else:
                    eta_t = group['lr'] * (torch.sqrt((v_hat / (state['v_hat_prev'] + group['eps'])).mean()).clamp(max=10))

                p.data.addcdiv_(m_hat, torch.sqrt(v_hat) + group['eps'], value=-eta_t)
                state['v_hat_prev'] = v_hat.clone()

        return loss

# ข้อมูลจำลองของ dataset และ model สำหรับ pose estimation
class DummyPoseEstimationDataset(Dataset):
    def __init__(self):
        self.data = torch.randn(100, 3, 224, 224)
        self.labels = torch.randint(0, 2, (100, 17, 2))  # 17 จุดสำหรับ pose estimation, 2 classes for simplicity

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

class SimplePoseEstimationModel(nn.Module):
    def __init__(self):
        super(SimplePoseEstimationModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)  # Adding max pooling layer
        self.fc = nn.Linear(128 * 56 * 56, 17 * 2)  # Adjusting input size for linear layer

    def forward(self, x):
        x = torch.relu(self.conv1(x))
        x = self.pool(x)
        x = torch.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x.view(-1, 17, 2)

# การเตรียม dataset และ dataloader
dataset = DummyPoseEstimationDataset()
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# การเตรียมโมเดล
model = SimplePoseEstimationModel()

# การเตรียม loss function
criterion = nn.CrossEntropyLoss()

# ปรับค่า hyperparameters ของ AdaMomentum
learning_rates = [0.001, 0.0001, 0.00001]
betas_list = [(0.9, 0.999), (0.9, 0.9), (0.8, 0.888)]

best_loss = float('inf')
best_params = None

for lr in learning_rates:
    for betas in betas_list:
        optimizer = AdaMomentum(model.parameters(), lr=lr, betas=betas, eps=1e-8, weight_decay=0)
        model.apply(lambda m: m.reset_parameters() if hasattr(m, 'reset_parameters') else None)  # Reset model parameters
        epoch_stats = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'duration': []}
        
        for epoch in range(10):  # Reduced to 10 epochs for hyperparameter tuning
            model.train()
            running_loss = 0.0
            all_preds = []
            all_labels = []
            start_time = time.time()

            for inputs, labels in dataloader:
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs.view(-1, 2), labels.view(-1, 2).max(1)[1])
                loss.backward()
                optimizer.step()
                running_loss += loss.item()

                preds = outputs.argmax(dim=-1).view(-1).cpu().numpy()
                labels = labels.view(-1, 2).max(1)[1].cpu().numpy()
                all_preds.extend(preds)
                all_labels.extend(labels)

            duration = time.time() - start_time
            avg_loss = running_loss / len(dataloader)
            accuracy = (np.array(all_preds) == np.array(all_labels)).mean() * 100
            f1 = f1_score(all_labels, all_preds, average='macro')
            precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
            recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)

            epoch_stats['loss'].append(avg_loss)
            epoch_stats['accuracy'].append(accuracy)
            epoch_stats['f1'].append(f1)
            epoch_stats['precision'].append(precision)
            epoch_stats['recall'].append(recall)
            epoch_stats['duration'].append(duration)

            print(f'AdaMomentum: lr={lr}, betas={betas}, Epoch [{epoch+1}/10], Loss: {avg_loss:.4f}, '
                  f'Accuracy: {accuracy:.2f}%, F1: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, '
                  f'Duration: {duration:.2f} seconds')
        
        if avg_loss < best_loss:
            best_loss = avg_loss
            best_params = (lr, betas)

print(f'Best AdaMomentum parameters: lr={best_params[0]}, betas={best_params[1]}, Loss={best_loss:.4f}')

# การเปรียบเทียบ Optimizers
optimizers = {
    'AdaMomentum': AdaMomentum(model.parameters(), lr=best_params[0], betas=best_params[1], eps=1e-8, weight_decay=0),
    'SGD': optim.SGD(model.parameters(), lr=0.01, momentum=0.9),
    'Adam': optim.Adam(model.parameters(), lr=0.001),
    'RMSprop': optim.RMSprop(model.parameters(), lr=0.001),
    'Adagrad': optim.Adagrad(model.parameters(), lr=0.01),
    'AdamW': optim.AdamW(model.parameters(), lr=0.001)
}

# การฝึกฝนโมเดลและเก็บค่า loss, accuracy, f1, precision, recall
num_epochs = 10
results = {}

for opt_name, optimizer in optimizers.items():
    model.apply(lambda m: m.reset_parameters() if hasattr(m, 'reset_parameters') else None)  # Reset model parameters
    epoch_stats = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'duration': []}
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        all_preds = []
        all_labels = []
        start_time = time.time()

        for inputs, labels in dataloader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs.view(-1, 2), labels.view(-1, 2).max(1)[1])
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

            preds = outputs.argmax(dim=-1).view(-1).cpu().numpy()
            labels = labels.view(-1, 2).max(1)[1].cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels)

        duration = time.time() - start_time
        avg_loss = running_loss / len(dataloader)
        accuracy = (np.array(all_preds) == np.array(all_labels)).mean() * 100
        f1 = f1_score(all_labels, all_preds, average='macro')
        precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
        recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)

        epoch_stats['loss'].append(avg_loss)
        epoch_stats['accuracy'].append(accuracy)
        epoch_stats['f1'].append(f1)
        epoch_stats['precision'].append(precision)
        epoch_stats['recall'].append(recall)
        epoch_stats['duration'].append(duration)

        print(f'Optimizer: {opt_name}, Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, '
              f'Accuracy: {accuracy:.2f}%, F1: {f1:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, '
              f'Duration: {duration:.2f} seconds')

    results[opt_name] = epoch_stats

# การแสดงผลลัพธ์
metrics = ['loss', 'accuracy', 'f1', 'precision', 'recall', 'duration']
plt.figure(figsize=(15, 10))
for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 3, i)
    for opt_name, stats in results.items():
        plt.plot(range(1, num_epochs+1), stats[metric], label=opt_name)
    plt.xlabel('Epoch')
    plt.ylabel(metric.capitalize())
    plt.title(f'{metric.capitalize()} per Epoch')
    plt.legend()
    plt.grid(True)
plt.tight_layout()
plt.show()

# สรุปผลลัพธ์ในรูปแบบตาราง
summary = {
    'Optimizer': [],
    'Final Loss': [],
    'Final Accuracy': [],
    'Final F1': [],
    'Final Precision': [],
    'Final Recall': [],
    'Average Duration per Epoch': []
}

for opt_name, stats in results.items():
    summary['Optimizer'].append(opt_name)
    summary['Final Loss'].append(stats['loss'][-1])
    summary['Final Accuracy'].append(stats['accuracy'][-1])
    summary['Final F1'].append(stats['f1'][-1])
    summary['Final Precision'].append(stats['precision'][-1])
    summary['Final Recall'].append(stats['recall'][-1])
    summary['Average Duration per Epoch'].append(np.mean(stats['duration']))

summary_df = pd.DataFrame(summary)
print(summary_df)
# Out:
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [1/10], Loss: 17.3449, Accuracy: 59.88%, F1: 0.4626, Precision: 0.4623, Recall: 0.4629, Duration: 2.03 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [2/10], Loss: 0.6916, Accuracy: 72.65%, F1: 0.4779, Precision: 0.5312, Recall: 0.5092, Duration: 2.05 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [3/10], Loss: 0.6502, Accuracy: 74.71%, F1: 0.4473, Precision: 0.5898, Recall: 0.5058, Duration: 2.03 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [4/10], Loss: 0.6010, Accuracy: 73.47%, F1: 0.4704, Precision: 0.5429, Recall: 0.5092, Duration: 2.02 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [5/10], Loss: 0.5798, Accuracy: 75.35%, F1: 0.4604, Precision: 0.7271, Recall: 0.5140, Duration: 2.01 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [6/10], Loss: 0.5446, Accuracy: 75.18%, F1: 0.4405, Precision: 0.8755, Recall: 0.5059, Duration: 2.04 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [7/10], Loss: 0.5344, Accuracy: 75.29%, F1: 0.4453, Precision: 0.8760, Recall: 0.5082, Duration: 2.05 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [8/10], Loss: 0.5135, Accuracy: 77.12%, F1: 0.5155, Precision: 0.8830, Recall: 0.5445, Duration: 2.02 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [9/10], Loss: 0.4596, Accuracy: 77.12%, F1: 0.5370, Precision: 0.7835, Recall: 0.5546, Duration: 2.04 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.999), Epoch [10/10], Loss: 0.4207, Accuracy: 76.82%, F1: 0.5047, Precision: 0.8818, Recall: 0.5386, Duration: 2.04 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.9), Epoch [1/10], Loss: 15.2279, Accuracy: 63.59%, F1: 0.4928, Precision: 0.4932, Recall: 0.4938, Duration: 2.06 seconds
# AdaMomentum: lr=0.001, betas=(0.9, 0.9), Epoch [2/10], Loss: 0.6919, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration:
# Optimizer: AdaMomentum, Epoch [4/10], Loss: 0.4931, Accuracy: 80.00%, F1: 0.6116, Precision: 0.8892, Recall: 0.6027, Duration: 2.13 seconds
# Optimizer: AdaMomentum, Epoch [5/10], Loss: 0.4206, Accuracy: 82.35%, F1: 0.7224, Precision: 0.7960, Recall: 0.6954, Duration: 2.11 seconds
# Optimizer: AdaMomentum, Epoch [6/10], Loss: 0.3037, Accuracy: 87.65%, F1: 0.7989, Precision: 0.9292, Recall: 0.7541, Duration: 2.09 seconds
# Optimizer: AdaMomentum, Epoch [7/10], Loss: 0.1975, Accuracy: 92.88%, F1: 0.8948, Precision: 0.9566, Recall: 0.8583, Duration: 2.10 seconds
# Optimizer: AdaMomentum, Epoch [8/10], Loss: 0.1092, Accuracy: 99.47%, F1: 0.9929, Precision: 0.9965, Recall: 0.9895, Duration: 2.12 seconds
# Optimizer: AdaMomentum, Epoch [9/10], Loss: 0.0550, Accuracy: 99.94%, F1: 0.9992, Precision: 0.9996, Recall: 0.9988, Duration: 2.11 seconds
# Optimizer: AdaMomentum, Epoch [10/10], Loss: 0.0273, Accuracy: 100.00%, F1: 1.0000, Precision: 1.0000, Recall: 1.0000, Duration: 2.14 seconds
# Optimizer: SGD, Epoch [1/10], Loss: 2.3357, Accuracy: 66.12%, F1: 0.4841, Precision: 0.4880, Recall: 0.4913, Duration: 1.96 seconds
# Optimizer: SGD, Epoch [2/10], Loss: 0.6672, Accuracy: 68.18%, F1: 0.6363, Precision: 0.6356, Recall: 0.6723, Duration: 1.94 seconds
# Optimizer: SGD, Epoch [3/10], Loss: 0.5763, Accuracy: 76.59%, F1: 0.4960, Precision: 0.8809, Recall: 0.5340, Duration: 1.94 seconds
# Optimizer: SGD, Epoch [4/10], Loss: 0.5322, Accuracy: 77.47%, F1: 0.5330, Precision: 0.8548, Recall: 0.5539, Duration: 1.98 seconds
# Optimizer: SGD, Epoch [5/10], Loss: 0.4865, Accuracy: 76.41%, F1: 0.4894, Precision: 0.8802, Recall: 0.5304, Duration: 1.97 seconds
# Optimizer: SGD, Epoch [6/10], Loss: 0.4311, Accuracy: 76.71%, F1: 0.5004, Precision: 0.8814, Recall: 0.5363, Duration: 1.95 seconds
# Optimizer: SGD, Epoch [7/10], Loss: 0.3878, Accuracy: 87.24%, F1: 0.7904, Precision: 0.9272, Recall: 0.7459, Duration: 1.93 seconds
# Optimizer: SGD, Epoch [8/10], Loss: 0.3796, Accuracy: 87.76%, F1: 0.8092, Precision: 0.8990, Recall: 0.7704, Duration: 1.94 seconds
# Optimizer: SGD, Epoch [9/10], Loss: 0.2891, Accuracy: 92.82%, F1: 0.8966, Precision: 0.9395, Recall: 0.8680, Duration: 1.96 seconds
# Optimizer: SGD, Epoch [10/10], Loss: 0.2161, Accuracy: 91.24%, F1: 0.8667, Precision: 0.9476, Recall: 0.8255, Duration: 1.98 seconds
# Optimizer: Adam, Epoch [1/10], Loss: 25.0355, Accuracy: 61.65%, F1: 0.4949, Precision: 0.4950, Recall: 0.4949, Duration: 2.06 seconds
# Optimizer: Adam, Epoch [2/10], Loss: 0.8918, Accuracy: 40.71%, F1: 0.4064, Precision: 0.5178, Recall: 0.5193, Duration: 2.00 seconds
# Optimizer: Adam, Epoch [3/10], Loss: 0.6927, Accuracy: 59.82%, F1: 0.5220, Precision: 0.5256, Recall: 0.5310, Duration: 1.97 seconds
# Optimizer: Adam, Epoch [4/10], Loss: 0.6916, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 2.02 seconds
# Optimizer: Adam, Epoch [5/10], Loss: 0.6900, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.96 seconds
# Optimizer: Adam, Epoch [6/10], Loss: 0.6884, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.99 seconds
# Optimizer: Adam, Epoch [7/10], Loss: 0.6871, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.99 seconds
# Optimizer: Adam, Epoch [8/10], Loss: 0.6854, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: Adam, Epoch [9/10], Loss: 0.6832, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: Adam, Epoch [10/10], Loss: 0.6824, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 2.01 seconds
# Optimizer: RMSprop, Epoch [1/10], Loss: 593.3284, Accuracy: 62.41%, F1: 0.4944, Precision: 0.4944, Recall: 0.4946, Duration: 1.95 seconds
# Optimizer: RMSprop, Epoch [2/10], Loss: 0.5677, Accuracy: 76.82%, F1: 0.5119, Precision: 0.8337, Recall: 0.5418, Duration: 1.95 seconds
# Optimizer: RMSprop, Epoch [3/10], Loss: 0.5190, Accuracy: 76.65%, F1: 0.4982, Precision: 0.8811, Recall: 0.5351, Duration: 1.95 seconds
# Optimizer: RMSprop, Epoch [4/10], Loss: 0.4723, Accuracy: 77.35%, F1: 0.5239, Precision: 0.8839, Recall: 0.5492, Duration: 1.93 seconds
# Optimizer: RMSprop, Epoch [5/10], Loss: 0.4436, Accuracy: 80.35%, F1: 0.6312, Precision: 0.8572, Recall: 0.6159, Duration: 1.95 seconds
# Optimizer: RMSprop, Epoch [6/10], Loss: 0.4772, Accuracy: 79.65%, F1: 0.6945, Precision: 0.7341, Recall: 0.6766, Duration: 1.96 seconds
# Optimizer: RMSprop, Epoch [7/10], Loss: 0.4140, Accuracy: 84.00%, F1: 0.7304, Precision: 0.8706, Recall: 0.6947, Duration: 2.04 seconds
# Optimizer: RMSprop, Epoch [8/10], Loss: 0.4580, Accuracy: 78.94%, F1: 0.7006, Precision: 0.7188, Recall: 0.6890, Duration: 1.97 seconds
# Optimizer: RMSprop, Epoch [9/10], Loss: 0.3809, Accuracy: 82.24%, F1: 0.6734, Precision: 0.9041, Recall: 0.6464, Duration: 1.95 seconds
# Optimizer: RMSprop, Epoch [10/10], Loss: 0.3727, Accuracy: 88.53%, F1: 0.8177, Precision: 0.9280, Recall: 0.7740, Duration: 1.96 seconds
# Optimizer: Adagrad, Epoch [1/10], Loss: 646.1840, Accuracy: 59.53%, F1: 0.4981, Precision: 0.5002, Recall: 0.5002, Duration: 1.95 seconds
# Optimizer: Adagrad, Epoch [2/10], Loss: 0.5720, Accuracy: 74.94%, F1: 0.4833, Precision: 0.6333, Recall: 0.5214, Duration: 1.96 seconds
# Optimizer: Adagrad, Epoch [3/10], Loss: 0.5084, Accuracy: 76.24%, F1: 0.4826, Precision: 0.8795, Recall: 0.5269, Duration: 1.94 seconds
# Optimizer: Adagrad, Epoch [4/10], Loss: 0.4945, Accuracy: 76.94%, F1: 0.5090, Precision: 0.8823, Recall: 0.5410, Duration: 1.95 seconds
# Optimizer: Adagrad, Epoch [5/10], Loss: 0.4856, Accuracy: 77.71%, F1: 0.5363, Precision: 0.8853, Recall: 0.5562, Duration: 1.92 seconds
# Optimizer: Adagrad, Epoch [6/10], Loss: 0.4180, Accuracy: 79.71%, F1: 0.6014, Precision: 0.8934, Recall: 0.5960, Duration: 1.94 seconds
# Optimizer: Adagrad, Epoch [7/10], Loss: 0.6501, Accuracy: 71.53%, F1: 0.5600, Precision: 0.5831, Recall: 0.5578, Duration: 1.96 seconds
# Optimizer: Adagrad, Epoch [8/10], Loss: 0.4341, Accuracy: 77.12%, F1: 0.5155, Precision: 0.8830, Recall: 0.5445, Duration: 1.94 seconds
# Optimizer: Adagrad, Epoch [9/10], Loss: 0.4030, Accuracy: 78.35%, F1: 0.5583, Precision: 0.8879, Recall: 0.5691, Duration: 1.93 seconds
# Optimizer: Adagrad, Epoch [10/10], Loss: 0.3831, Accuracy: 79.24%, F1: 0.5868, Precision: 0.8915, Recall: 0.5867, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [1/10], Loss: 23.6937, Accuracy: 66.18%, F1: 0.4908, Precision: 0.4951, Recall: 0.4963, Duration: 2.14 seconds
# Optimizer: AdamW, Epoch [2/10], Loss: 1.3589, Accuracy: 35.94%, F1: 0.3558, Precision: 0.5351, Recall: 0.5271, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [3/10], Loss: 0.6922, Accuracy: 70.12%, F1: 0.4951, Precision: 0.5181, Recall: 0.5094, Duration: 1.95 seconds
# Optimizer: AdamW, Epoch [4/10], Loss: 0.6909, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [5/10], Loss: 0.6898, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [6/10], Loss: 0.6883, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.97 seconds
# Optimizer: AdamW, Epoch [7/10], Loss: 0.6862, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [8/10], Loss: 0.6853, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.97 seconds
# Optimizer: AdamW, Epoch [9/10], Loss: 0.6829, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.98 seconds
# Optimizer: AdamW, Epoch [10/10], Loss: 0.6827, Accuracy: 74.88%, F1: 0.4282, Precision: 0.3744, Recall: 0.5000, Duration: 1.99 seconds
#      Optimizer  Final Loss  Final Accuracy  Final F1  Final Precision  \
# 0  AdaMomentum    0.027295      100.000000  1.000000         1.000000
# 1          SGD    0.216138       91.235294  0.866682         0.947609
# 2         Adam    0.682440       74.882353  0.428187         0.374412
# 3      RMSprop    0.372660       88.529412  0.817734         0.928034
# 4      Adagrad    0.383113       79.235294  0.586822         0.891451
# 5        AdamW    0.682732       74.882353  0.428187         0.374412
#
#    Final Recall  Average Duration per Epoch
# 0      1.000000                    2.117349
# 1      0.825527                    1.954162
# 2      0.500000                    1.997060
# 3      0.773997                    1.959671
# 4      0.586651                    1.948007
# 5      0.500000                    1.991037
